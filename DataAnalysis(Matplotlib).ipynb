# %% [markdown]
# <a href="https://colab.research.google.com/github/RJ2517/python-ml-projects/blob/main/DataAnalysis(Matplotlib).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("employee_data.csv")
data.head()
# Out:
#     Name  Age  Salary  Experience  PerformanceScore
# 0   Amit   25   30000           2                70
# 1  Rohit   30   50000           5                85
# 2  Sneha   28   45000           4                80
# 3  Priya   35   65000           8                90
# 4  Vikas   40   80000          12                95

# %%
print(data.info())
print(data.describe())

average_salary = data["Salary"].mean()
print("Average Salary:", average_salary)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              10 non-null     object
#  1   Age               10 non-null     int64
#  2   Salary            10 non-null     int64
#  3   Experience        10 non-null     int64
#  4   PerformanceScore  10 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 532.0+ bytes
# None
#              Age        Salary  Experience  PerformanceScore
# count  10.000000     10.000000   10.000000         10.000000
# mean   31.700000  53700.000000    6.000000         84.300000
# std     5.012207  16159.276661    3.299832          8.313978
# min    25.000000  30000.000000    2.000000         70.000000
# 25%    28.250000  45750.000000    4.000000         80.500000
# 50%    31.000000  52500.000000    5.500000         86.500000
# ...

# %%
plt.bar(data["Name"], data["Salary"])
plt.xlabel("Employee Name")
plt.ylabel("Salary")
plt.title("Salary Comparison of Employees")
plt.show()

# %%
plt.scatter(data["Experience"], data["Salary"])
plt.xlabel("Experience (Years)")
plt.ylabel("Salary")
plt.title("Experience vs Salary")
plt.show()

# %%
# Select only numeric columns
numeric_data = data.select_dtypes(include=[np.number])

# Correlation matrix
correlation = numeric_data.corr()

# Plot heatmap
plt.imshow(correlation, cmap="hot")
plt.colorbar()
plt.xticks(range(len(correlation)), correlation.columns, rotation=45)
plt.yticks(range(len(correlation)), correlation.columns)
plt.title("Correlation Heatmap")
plt.show()
